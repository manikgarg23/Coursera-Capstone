# %% [markdown]
# Toronto neighborhoods
# In this assignment, you will be required to explore, segment, and cluster the neighborhoods in the city of Toronto.
#
# The neighborhood data for Toronto is not readily available on the internet. However, a Wikipedia page exists that has all the information we need to explore and cluster the neighborhoods in Toronto and New York.
#
# We Get the data, clean it, and then read it into a pandas dataframe so that it is in a suitable structured format.
#
# Once the data is in a structured format, can analyze the dataset to explore and cluster the neighborhoods in the city of Toronto and New York
#
# Let's start!

# %%
# !conda install -c conda-forge geopy --yes           # uncomment only if it is necessary to install the 'geopy' library
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.19.0-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  21.04 MB/s
# geopy-1.19.0-p 100% |################################| Time: 0:00:00  33.55 MB/s

# %%
import pandas as pd

# %% [markdown]
# Part 1: Postal codes
# Scrape the Wikipedia page https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M in order
#
# 1) to obtain the data that is in the table of postal codes and
#
# 2) to transform the data into a pandas dataframe of the postal code of each neighborhood along with the borough name and neighborhood name.
#
# 1.1. Obtain the data
# Use the BeautifulSoup package or any other way you are comfortable with to transform the data in the table on the Wikipedia page into the pandas dataframe.
#
# Instead of BeautifulSoup package, I preferred to use the function 'read_html' from Pandas to read the HTML table into a dataframe.

# %%
df_cp = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]

# %%
df_cp.shape         # dataframe dimension (rows, columns)
# Out:
# (289, 3)

# %%
df_cp.columns
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
df_cp.head(3)            # dataframe display
# Out:
#           0             1              2
# 0  Postcode       Borough  Neighbourhood
# 1       M1A  Not assigned   Not assigned
# 2       M2A  Not assigned   Not assigned

# %% [markdown]
# transform data

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   PostalCode           Borough      Neighborhood
# 0        M1A      Not assigned      Not assigned
# 1        M2A      Not assigned      Not assigned
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront

# %%
df_data_1.rename(columns={'Postcode':'PostalCode', 'Neighbourhood':'Neighborhood'}, inplace=True)   # columns rename 
df_data_1.columns
# Out:
# Index(['PostalCode', 'Borough', 'Neighborhood'], dtype='object')

# %%
filter_1 = (df_data_1['Borough']!='Not assigned') # create a filter with the condition 'Borough' different to'Not assigned'
df_data_1 = df_data_1[filter_1]                       # apply the filter 
'Not assigned' is df_data_1['Borough']
# Out:
# False

# %%
df_data_1
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M5A  Downtown Toronto
# 6          M6A        North York
# 7          M6A        North York
# 8          M7A      Queen's Park
# 10         M9A         Etobicoke
# 11         M1B       Scarborough
# 12         M1B       Scarborough
# 14         M3B        North York
# 15         M4B         East York
# 16         M4B         East York
# 17         M5B  Downtown Toronto
# 18         M5B  Downtown Toronto
# 19         M6B        North York
# 22         M9B         Etobicoke
# 23         M9B         Etobicoke
# 24         M9B         Etobicoke
# 25         M9B         Etobicoke
# 26         M9B         Etobicoke
# 27         M1C       Scarborough
# 28         M1C       Scarborough
# 29         M1C       Scarborough
# 31         M3C        North York
# 32         M3C        North York
# 33         M4C         East York
# 34         M5C  Downtown Toronto
# 35         M6C              York
# 38         M9C         Etobicoke
# ..         ...               ...
# 235        M9V         Etobicoke
# 236        M1W       Scarborough
# 239        M4W  Downtown Toronto
# 240        M5W  Downtown Toronto
# 243        M8W         Etobicoke
# 244        M8W         Etobicoke
# 245        M9W         Etobicoke
# 246        M1X       Scarborough
# 249        M4X  Downtown Toronto
# 250        M4X  Downtown Toronto
# 251        M5X  Downtown Toronto
# 252        M5X  Downtown Toronto
# 255        M8X         Etobicoke
# 256        M8X         Etobicoke
# 257        M8X         Etobicoke
# 262        M4Y  Downtown Toronto
# 265        M7Y      East Toronto
# 266        M8Y         Etobicoke
# 267        M8Y         Etobicoke
# 268        M8Y         Etobicoke
# 269        M8Y         Etobicoke
# 270        M8Y         Etobicoke
# 271        M8Y         Etobicoke
# 272        M8Y         Etobicoke
# 273        M8Y         Etobicoke
# 282        M8Z         Etobicoke
# 283        M8Z         Etobicoke
# 284        M8Z         Etobicoke
# 285        M8Z         Etobicoke
# 286        M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38                                   Bloordale Gardens
# ..                                                 ...
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                                          Alderwood
# 244                                        Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                                        Cabbagetown
# 250                                     St. James Town
# 251                               First Canadian Place
# 252                                   Underground city
# 255                                       The Kingsway
# 256                                    Montgomery Road
# 257                                     Old Mill North
# 262                               Church and Wellesley
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
#
# [211 rows x 3 columns]

# %% [markdown]
# If a cell has a borough but a 'Not assigned' neighborhood, then the neighborhood will be the same as the borough.

# %%
filter_21 = (df_data_1['Neighborhood'] == 'Not assigned')   # create a filter
labels_21 = df_data_1[filter_21].index                       # apply the filter and get the row labels
df_data_1[filter_21]
# Out:
#   PostalCode       Borough  Neighborhood
# 8        M7A  Queen's Park  Not assigned

# %%
# Change 'Neighborhood' if it is 'Not assigned'
# 1 - Valid only in this case, where filter_2 only has 1 element.
#df_cp.loc[rows_2[0]]['Neighbourhood'] = df_cp.loc[rows_2[0]]['Borough']  # df.loc - access to a row by label

# 2 - Valid in general, for any filter size.
for i in labels_21:                                             
    df_data_1.loc[i]['Neighborhood'] = df_data_1.loc[i]['Borough']

# %%
print('Not assigned' in df_data_1['Neighborhood'])
# Out:
# False

# %%
filter_22 = (df_data_1['Neighborhood'] == 'Not assigned')    # second      
df_data_1[filter_22]
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood]
# Index: []

# %%
df_data_1.loc[[8]]                                            # third
# Out:
#   PostalCode       Borough  Neighborhood
# 8        M7A  Queen's Park  Queen's Park

# %% [markdown]
# When more than one neighborhood exists in one postal code area, these rows will be combined into one row with the neighborhoods separated with a comma.

# %%
df_data_1
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M5A  Downtown Toronto
# 6          M6A        North York
# 7          M6A        North York
# 8          M7A      Queen's Park
# 10         M9A         Etobicoke
# 11         M1B       Scarborough
# 12         M1B       Scarborough
# 14         M3B        North York
# 15         M4B         East York
# 16         M4B         East York
# 17         M5B  Downtown Toronto
# 18         M5B  Downtown Toronto
# 19         M6B        North York
# 22         M9B         Etobicoke
# 23         M9B         Etobicoke
# 24         M9B         Etobicoke
# 25         M9B         Etobicoke
# 26         M9B         Etobicoke
# 27         M1C       Scarborough
# 28         M1C       Scarborough
# 29         M1C       Scarborough
# 31         M3C        North York
# 32         M3C        North York
# 33         M4C         East York
# 34         M5C  Downtown Toronto
# 35         M6C              York
# 38         M9C         Etobicoke
# ..         ...               ...
# 235        M9V         Etobicoke
# 236        M1W       Scarborough
# 239        M4W  Downtown Toronto
# 240        M5W  Downtown Toronto
# 243        M8W         Etobicoke
# 244        M8W         Etobicoke
# 245        M9W         Etobicoke
# 246        M1X       Scarborough
# 249        M4X  Downtown Toronto
# 250        M4X  Downtown Toronto
# 251        M5X  Downtown Toronto
# 252        M5X  Downtown Toronto
# 255        M8X         Etobicoke
# 256        M8X         Etobicoke
# 257        M8X         Etobicoke
# 262        M4Y  Downtown Toronto
# 265        M7Y      East Toronto
# 266        M8Y         Etobicoke
# 267        M8Y         Etobicoke
# 268        M8Y         Etobicoke
# 269        M8Y         Etobicoke
# 270        M8Y         Etobicoke
# 271        M8Y         Etobicoke
# 272        M8Y         Etobicoke
# 273        M8Y         Etobicoke
# 282        M8Z         Etobicoke
# 283        M8Z         Etobicoke
# 284        M8Z         Etobicoke
# 285        M8Z         Etobicoke
# 286        M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Queen's Park
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38                                   Bloordale Gardens
# ..                                                 ...
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                                          Alderwood
# 244                                        Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                                        Cabbagetown
# 250                                     St. James Town
# 251                               First Canadian Place
# 252                                   Underground city
# 255                                       The Kingsway
# 256                                    Montgomery Road
# 257                                     Old Mill North
# 262                               Church and Wellesley
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
#
# [211 rows x 3 columns]

# %%
print('The city of Toronto has {} boroughs, {} postal codes and {} neighborhoods.'.format(
       len(df_data_1['Borough'].unique()),len(df_data_1['PostalCode'].unique()), df_data_1.shape[0]))
# Out:
# The city of Toronto has 11 boroughs, 103 postal codes and 211 neighborhoods.

# %%
filter_3 = df_data_1[['PostalCode']].duplicated()
labels_3 = df_data_1[filter_3].index
labels_3
# Out:
# Int64Index([  5,   7,  12,  16,  18,  23,  24,  25,  26,  28,
#             ...
#             268, 269, 270, 271, 272, 273, 283, 284, 285, 286],
#            dtype='int64', length=108)

# %% [markdown]
# combine the neighborhoods for these postal codes into one row:

# %%
for k in range(labels_3.size):
    neigh = df_data_1.loc[labels_3[k]]['Neighborhood']  # get neighborhood to combine
    row = df_data_1.index.get_loc(labels_3[k])          # get the row label origen
    df_data_1.iloc[row-1]['Neighborhood'] = df_data_1.iloc[row-1]['Neighborhood'] + ',' + neigh   # combine
    df_data_1 = df_data_1.drop(labels_3[k], axis=0)

# %%
df_data_1
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 6          M6A        North York
# 8          M7A      Queen's Park
# 10         M9A         Etobicoke
# 11         M1B       Scarborough
# 14         M3B        North York
# 15         M4B         East York
# 17         M5B  Downtown Toronto
# 19         M6B        North York
# 22         M9B         Etobicoke
# 27         M1C       Scarborough
# 31         M3C        North York
# 33         M4C         East York
# 34         M5C  Downtown Toronto
# 35         M6C              York
# 38         M9C         Etobicoke
# 42         M1E       Scarborough
# 47         M4E      East Toronto
# 48         M5E  Downtown Toronto
# 49         M6E              York
# 53         M1G       Scarborough
# 56         M4G         East York
# 57         M5G  Downtown Toronto
# 58         M6G  Downtown Toronto
# 62         M1H       Scarborough
# 63         M2H        North York
# 64         M3H        North York
# 67         M4H         East York
# ..         ...               ...
# 168        M4R   Central Toronto
# 169        M5R   Central Toronto
# 172        M6R      West Toronto
# 174        M7R       Mississauga
# 176        M9R         Etobicoke
# 180        M1S       Scarborough
# 183        M4S   Central Toronto
# 184        M5S  Downtown Toronto
# 186        M6S      West Toronto
# 191        M1T       Scarborough
# 196        M4T   Central Toronto
# 198        M5T  Downtown Toronto
# 205        M1V       Scarborough
# 211        M4V   Central Toronto
# 216        M5V  Downtown Toronto
# 225        M8V         Etobicoke
# 228        M9V         Etobicoke
# 236        M1W       Scarborough
# 239        M4W  Downtown Toronto
# 240        M5W  Downtown Toronto
# 243        M8W         Etobicoke
# 245        M9W         Etobicoke
# 246        M1X       Scarborough
# 249        M4X  Downtown Toronto
# 251        M5X  Downtown Toronto
# 255        M8X         Etobicoke
# 262        M4Y  Downtown Toronto
# 265        M7Y      East Toronto
# 266        M8Y         Etobicoke
# 282        M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                             Harbourfront,Regent Park
# 6                      Lawrence Heights,Lawrence Manor
# 8                                         Queen's Park
# 10                                    Islington Avenue
# 11                                       Rouge,Malvern
# 14                                     Don Mills North
# 15                      Woodbine Gardens,Parkview Hill
# 17                             Ryerson,Garden District
# 19                                           Glencairn
# 22   Cloverdale,Islington,Martin Grove,Princess Gar...
# 27                Highland Creek,Rouge Hill,Port Union
# 31                     Flemingdon Park,Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38   Bloordale Gardens,Eringate,Markland Wood,Old B...
# 42                     Guildwood,Morningside,West Hill
# 47                                         The Beaches
# 48                                         Berczy Park
# 49                                 Caledonia-Fairbanks
# 53                                              Woburn
# 56                                             Leaside
# 57                                  Central Bay Street
# 58                                            Christie
# 62                                           Cedarbrae
# 63                                   Hillcrest Village
# 64       Bathurst Manor,Downsview North,Wilson Heights
# 67                                    Thorncliffe Park
# ..                                                 ...
# 168                                 North Toronto West
# 169                  The Annex,North Midtown,Yorkville
# 172                              Parkdale,Roncesvalles
# 174              Canada Post Gateway Processing Centre
# 176  Kingsview Village,Martin Grove Gardens,Richvie...
# 180                                          Agincourt
# 183                                         Davisville
# 184                      Harbord,University of Toronto
# 186                                  Runnymede,Swansea
# 191              Clarks Corners,Sullivan,Tam O'Shanter
# 196                         Moore Park,Summerhill East
# 198            Chinatown,Grange Park,Kensington Market
# 205  Agincourt North,L'Amoreaux East,Milliken,Steel...
# 211  Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 216  CN Tower,Bathurst Quay,Island airport,Harbourf...
# 225         Humber Bay Shores,Mimico South,New Toronto
# 228  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                              Alderwood,Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                         Cabbagetown,St. James Town
# 251              First Canadian Place,Underground city
# 255        The Kingsway,Montgomery Road,Old Mill North
# 262                               Church and Wellesley
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266  Humber Bay,King's Mill Park,Kingsway Park Sout...
# 282  Kingsway Park South West,Mimico NW,The Queensw...
#
# [103 rows x 3 columns]

# %% [markdown]
# Change the row labels to match the ones in the required dataframe

# %%
df_data_1 = df_data_1.reset_index(drop = True)        # rows rename 
df_data_1
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# 27         M2H        North York
# 28         M3H        North York
# 29         M4H         East York
# ..         ...               ...
# 73         M4R   Central Toronto
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 76         M7R       Mississauga
# 77         M9R         Etobicoke
# 78         M1S       Scarborough
# 79         M4S   Central Toronto
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 90         M1W       Scarborough
# 91         M4W  Downtown Toronto
# 92         M5W  Downtown Toronto
# 93         M8W         Etobicoke
# 94         M9W         Etobicoke
# 95         M1X       Scarborough
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                             Harbourfront,Regent Park
# 3                      Lawrence Heights,Lawrence Manor
# 4                                         Queen's Park
# 5                                     Islington Avenue
# 6                                        Rouge,Malvern
# 7                                      Don Mills North
# 8                       Woodbine Gardens,Parkview Hill
# 9                              Ryerson,Garden District
# 10                                           Glencairn
# 11   Cloverdale,Islington,Martin Grove,Princess Gar...
# 12                Highland Creek,Rouge Hill,Port Union
# 13                     Flemingdon Park,Don Mills South
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Bloordale Gardens,Eringate,Markland Wood,Old B...
# 18                     Guildwood,Morningside,West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28       Bathurst Manor,Downsview North,Wilson Heights
# 29                                    Thorncliffe Park
# ..                                                 ...
# 73                                  North Toronto West
# 74                   The Annex,North Midtown,Yorkville
# 75                               Parkdale,Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 77   Kingsview Village,Martin Grove Gardens,Richvie...
# 78                                           Agincourt
# 79                                          Davisville
# 80                       Harbord,University of Toronto
# 81                                   Runnymede,Swansea
# 82               Clarks Corners,Sullivan,Tam O'Shanter
# 83                          Moore Park,Summerhill East
# 84             Chinatown,Grange Park,Kensington Market
# 85   Agincourt North,L'Amoreaux East,Milliken,Steel...
# 86   Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 87   CN Tower,Bathurst Quay,Island airport,Harbourf...
# 88          Humber Bay Shores,Mimico South,New Toronto
# 89   Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 90                                     L'Amoreaux West
# 91                                            Rosedale
# 92                     Stn A PO Boxes 25 The Esplanade
# 93                               Alderwood,Long Branch
# 94                                           Northwest
# 95                                         Upper Rouge
# 96                          Cabbagetown,St. James Town
# 97               First Canadian Place,Underground city
# 98         The Kingsway,Montgomery Road,Old Mill North
# 99                                Church and Wellesley
# 100  Business Reply Mail Processing Centre 969 Eastern
# 101  Humber Bay,King's Mill Park,Kingsway Park Sout...
# 102  Kingsway Park South West,Mimico NW,The Queensw...
#
# [103 rows x 3 columns]

# %% [markdown]
# In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %%
print('The number of rows of my postal codes dataframe is: ', df_data_1.shape[0])
# Out:
# The number of rows of my postal codes dataframe is:  103

# %% [markdown]
# OBtain the data

# %%
df_gc = pd.read_csv('http://cocl.us/Geospatial_data')

# %%
df_gc.shape
# Out:
# (103, 3)

# %%
df_gc.columns
# Out:
# Index(['Postal Code', 'Latitude', 'Longitude'], dtype='object')

# %%
df_gc.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_gc.rename(columns = {'Postal Code':'PostalCode'}, inplace = True)

# %%
df_gc.columns
# Out:
# Index(['PostalCode', 'Latitude', 'Longitude'], dtype='object')

# %%
df_tn = df_data_1.merge(df_gc, on = 'PostalCode')
df_tn
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# 27         M2H        North York
# 28         M3H        North York
# 29         M4H         East York
# ..         ...               ...
# 73         M4R   Central Toronto
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 76         M7R       Mississauga
# 77         M9R         Etobicoke
# 78         M1S       Scarborough
# 79         M4S   Central Toronto
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 90         M1W       Scarborough
# 91         M4W  Downtown Toronto
# 92         M5W  Downtown Toronto
# 93         M8W         Etobicoke
# 94         M9W         Etobicoke
# 95         M1X       Scarborough
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                             Harbourfront,Regent Park  43.654260 -79.360636
# 3                      Lawrence Heights,Lawrence Manor  43.718518 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                        Rouge,Malvern  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                       Woodbine Gardens,Parkview Hill  43.706397 -79.309937
# 9                              Ryerson,Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale,Islington,Martin Grove,Princess Gar...  43.650943 -79.554724
# 12                Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 13                     Flemingdon Park,Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 18                     Guildwood,Morningside,West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                   The Annex,North Midtown,Yorkville  43.672710 -79.405678
# 75                               Parkdale,Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                       Harbord,University of Toronto  43.662696 -79.400049
# 81                                   Runnymede,Swansea  43.651571 -79.484450
# 82               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 83                          Moore Park,Summerhill East  43.689574 -79.383160
# 84             Chinatown,Grange Park,Kensington Market  43.653206 -79.400049
# 85   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 86   Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 87   CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
# 88          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 89   Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                               Alderwood,Long Branch  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                          Cabbagetown,St. James Town  43.667967 -79.367675
# 97               First Canadian Place,Underground city  43.648429 -79.382280
# 98         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  Humber Bay,King's Mill Park,Kingsway Park Sout...  43.636258 -79.498509
# 102  Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  43.29 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  36.46 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  36.89 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  46.51 MB/s

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.19.0                     py_0    conda-forge

# %%
# now, lets get the Toronto latitude and longitude
address = 'Toronto, ON'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# EXPLORE LOCATION

# %%
latitude = 43.662301
longitude = -79.389494

# %%
CLIENT_ID = 'VESEQ0WR5Y4X1O5LVJ0V4354ODR1SCLHVAIAJLACMFX0ETTP' # your Foursquare ID
CLIENT_SECRET = 'S5P4JAUQUSFNL5Y1ASAHTK210FAATWSCC0RIH54RAIGUKNVQ' # your Foursquare Secret
VERSION = '20190404'
LIMIT = 30
print('Your credentails:')
# Out:
# Your credentails:
# CLIENT_ID: VESEQ0WR5Y4X1O5LVJ0V4354ODR1SCLHVAIAJLACMFX0ETTP
# CLIENT_SECRET:S5P4JAUQUSFNL5Y1ASAHTK210FAATWSCC0RIH54RAIGUKNVQ

# %%
address = 'Queen Park, Toronto'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6529083 -79.3794575

# %%
search_query = 'Italian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
import requests # library to handle requests
from pandas.io.json import json_normalize

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cba061b9fb6b7770b27bde5'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'primary': True,
#       'shortName': 'Food Truck'}],
#     'hasPerk': False,
#     'id': '4c787c9181bca0936180fa14',
#     'location': {'address': 'CNE Midway',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 158,
#      'formattedAddress': ['CNE Midway', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652144,
#        'lng': -79.381118}],
#      'lat': 43.652144,
#      'lng': -79.381118,
#      'state': 'ON'},
#     'name': 'Classic italian style pizza food truck',
#     'referralId': 'v-1555695131'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '573df789498e03dd8e54b166',
#     'location': {'address': '595 Bay St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Dundas St',
#      'distance': 470,
#      'formattedAddress': ['595 Bay St (Dundas St)',
#       'Toronto ON M5G 2C2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65616,
#        'lng': -79.38319}],
#      'lat': 43.65616,
#      'lng': -79.38319,
#      'postalCode': 'M5G 2C2',
#      'state': 'ON'},
#     'name': 'Mustachio Italian Eatery',
#     'referralId': 'v-1555695131'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '4f88cf84e4b002b90ab3b9b9',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 491,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65053979517576,
#        'lng': -79.38460322737672}],
#      'lat': 43.65053979517576,
#      'lng': -79.38460322737672},
#     'name': "LA's Italian + Bar",
#     'referralId': 'v-1555695131'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '4b846dd4f964a520dc3431e3',
#     'location': {'address': '121 Richmond St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at York St.',
#      'distance': 500,
#      'formattedAddress': ['121 Richmond St. W (at York St.)',
#       'Toronto ON M5H 2K1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65029624519052,
#        'lng': -79.38451301997945}],
#      'lat': 43.65029624519052,
#      'lng': -79.38451301997945,
#      'postalCode': 'M5H 2K1',
#      'state': 'ON'},
#     'name': "Little Anthony's",
#     'referralId': 'v-1555695131',
#     'venuePage': {'id': '75877692'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'primary': True,
#       'shortName': 'Pizza'}],
#     'hasPerk': False,
#     'id': '4b4a2d09f964a520687d26e3',
#     'location': {'address': '220 Yonge St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'in Toronto Eaton Centre',
#      'distance': 316,
#      'formattedAddress': ['220 Yonge St. (in Toronto Eaton Centre)',
#       'Toronto ON M5B 2H1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655518,
#        'lng': -79.38103}],
#      'lat': 43.655518,
#      'lng': -79.38103,
#      'postalCode': 'M5B 2H1',
#      'state': 'ON'},
#     'name': 'Sbarro',
#     'referralId': 'v-1555695131'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'primary': True,
#       'shortName': 'Government'}],
#     'hasPerk': False,
#     'id': '516c1ef3e4b0b595c55461aa',
#     'location': {'address': 'Beverly',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Dundas',
#      'distance': 318,
#      'formattedAddress': ['Beverly (Dundas)', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6540714381019,
#        'lng': -79.37584957705431}],
#      'lat': 43.6540714381019,
#      'lng': -79.37584957705431,
#      'state': 'ON'},
#     'name': 'Consolato Italiano',
#     'referralId': 'v-1555695131'}]}}

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 4  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
#
#                          id    location.address location.cc location.city  \
# 0  4c787c9181bca0936180fa14          CNE Midway          CA       Toronto
# 1  573df789498e03dd8e54b166          595 Bay St          CA       Toronto
# 2  4f88cf84e4b002b90ab3b9b9                 NaN          CA           NaN
# 3  4b846dd4f964a520dc3431e3  121 Richmond St. W          CA       Toronto
# 4  4b4a2d09f964a520687d26e3       220 Yonge St.          CA       Toronto
#
#   location.country     location.crossStreet  location.distance  \
# 0           Canada                      NaN                158
# 1           Canada                Dundas St                470
# 2           Canada                      NaN                491
# 3           Canada              at York St.                500
# 4           Canada  in Toronto Eaton Centre                316
#
#                            location.formattedAddress  \
# 0                   [CNE Midway, Toronto ON, Canada]
# 1  [595 Bay St (Dundas St), Toronto ON M5G 2C2, C...
# 2                                           [Canada]
# 3  [121 Richmond St. W (at York St.), Toronto ON ...
# 4  [220 Yonge St. (in Toronto Eaton Centre), Toro...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.652144, 'lng':...     43.652144
# 1  [{'label': 'display', 'lat': 43.65616, 'lng': ...     43.656160
# 2  [{'label': 'display', 'lat': 43.65053979517576...     43.650540
# 3  [{'label': 'display', 'lat': 43.65029624519052...     43.650296
# 4  [{'label': 'display', 'lat': 43.655518, 'lng':...     43.655518
#
#    location.lng location.postalCode location.state  \
# 0    -79.381118                 NaN             ON
# 1    -79.383190             M5G 2C2             ON
# 2    -79.384603                 NaN            NaN
# 3    -79.384513             M5H 2K1             ON
# 4    -79.381030             M5B 2H1             ON
#
#                                      name    referralId venuePage.id
# 0  Classic italian style pizza food truck  v-1555695131          NaN
# 1                Mustachio Italian Eatery  v-1555695131          NaN
# 2                      LA's Italian + Bar  v-1555695131          NaN
# 3                        Little Anthony's  v-1555695131     75877692
# 4                                  Sbarro  v-1555695131          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                      name           categories  \
# 0  Classic italian style pizza food truck           Food Truck
# 1                Mustachio Italian Eatery   Italian Restaurant
# 2                      LA's Italian + Bar   Italian Restaurant
# 3                        Little Anthony's   Italian Restaurant
# 4                                  Sbarro          Pizza Place
# 5                      Consolato Italiano  Government Building
#
#               address  cc     city country              crossStreet  distance  \
# 0          CNE Midway  CA  Toronto  Canada                      NaN       158
# 1          595 Bay St  CA  Toronto  Canada                Dundas St       470
# 2                 NaN  CA      NaN  Canada                      NaN       491
# 3  121 Richmond St. W  CA  Toronto  Canada              at York St.       500
# 4       220 Yonge St.  CA  Toronto  Canada  in Toronto Eaton Centre       316
# 5             Beverly  CA  Toronto  Canada                   Dundas       318
#
#                                     formattedAddress  \
# 0                   [CNE Midway, Toronto ON, Canada]
# 1  [595 Bay St (Dundas St), Toronto ON M5G 2C2, C...
# 2                                           [Canada]
# 3  [121 Richmond St. W (at York St.), Toronto ON ...
# 4  [220 Yonge St. (in Toronto Eaton Centre), Toro...
# 5             [Beverly (Dundas), Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.652144, 'lng':...  43.652144 -79.381118
# 1  [{'label': 'display', 'lat': 43.65616, 'lng': ...  43.656160 -79.383190
# 2  [{'label': 'display', 'lat': 43.65053979517576...  43.650540 -79.384603
# 3  [{'label': 'display', 'lat': 43.65029624519052...  43.650296 -79.384513
# 4  [{'label': 'display', 'lat': 43.655518, 'lng':...  43.655518 -79.381030
# 5  [{'label': 'display', 'lat': 43.6540714381019,...  43.654071 -79.375850
#
#   postalCode state                        id
# 0        NaN    ON  4c787c9181bca0936180fa14
# 1    M5G 2C2    ON  573df789498e03dd8e54b166
# 2        NaN   NaN  4f88cf84e4b002b90ab3b9b9
# 3    M5H 2K1    ON  4b846dd4f964a520dc3431e3
# 4    M5B 2H1    ON  4b4a2d09f964a520687d26e3
# 5        NaN    ON  516c1ef3e4b0b595c55461aa

# %%
dataframe_filtered.name
# Out:
# 0    Classic italian style pizza food truck
# 1                  Mustachio Italian Eatery
# 2                        LA's Italian + Bar
# 3                          Little Anthony's
# 4                                    Sbarro
# 5                        Consolato Italiano
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=100,
    color='red',
    popup='Government Building', # Conrad Hotel
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# coffee Shop
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Coffee Shop',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
EXPLORE MORE

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=VESEQ0WR5Y4X1O5LVJ0V4354ODR1SCLHVAIAJLACMFX0ETTP&client_secret=S5P4JAUQUSFNL5Y1ASAHTK210FAATWSCC0RIH54RAIGUKNVQ&ll=43.6529083,-79.3794575&v=20190404&radius=500&limit=30'

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Ecco restaurant.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-506db1a9e4b0a3f3b31412f0-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d14e941735',
#     'name': 'American Restaurant',
#     'pluralName': 'American Restaurants',
#     'primary': True,
#     'shortName': 'American'}],
#   'id': '506db1a9e4b0a3f3b31412f0',
#   'location': {'address': '1 Richmond Street West',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'country': 'Canada',
#    'crossStreet': 'Yonge Street',
#    'distance': 149,
#    'formattedAddress': ['1 Richmond Street West (Yonge Street)',
#     'Toronto ON',
#     'Canada'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65156872562108,
#      'lng': -79.37926594000328}],
#    'lat': 43.65156872562108,
#    'lng': -79.37926594000328,
#    'state': 'ON'},
#   'name': 'Richmond Station',
#   'photos': {'count': 0, 'groups': []}}}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                 name           categories  \
# 0                   Richmond Station  American Restaurant
# 1   Elgin And Winter Garden Theatres              Theater
# 2            CF Toronto Eaton Centre        Shopping Mall
# 3                   GoodLife Fitness                  Gym
# 4                             Indigo            Bookstore
# 5  Eggspectation Bell Trinity Square       Breakfast Spot
# 6                               LUSH       Cosmetics Shop
# 7                      Old City Hall  Monument / Landmark
# 8                        Massey Hall         Concert Hall
# 9                            SEPHORA       Cosmetics Shop
#
#                           address  cc     city country  \
# 0          1 Richmond Street West  CA  Toronto  Canada
# 1                    189 Yonge St  CA  Toronto  Canada
# 2                    220 Yonge St  CA  Toronto  Canada
# 3                    137 Yonge St  CA  Toronto  Canada
# 4                    220 Yonge St  CA  Toronto  Canada
# 5                  483 Bay Street  CA  Toronto  Canada
# 6       220 Yonge St, Unit B215-A  CA  Toronto  Canada
# 7            60 Queen Street West  CA  Toronto  Canada
# 8                 178 Victoria St  CA  Toronto  Canada
# 9  220 Yonge Street, Space #3-131  CA  Toronto  Canada
#
#                    crossStreet  distance  \
# 0                 Yonge Street       149
# 1  btwn Queen St E & Shuter St        93
# 2          btwn Queen & Dundas       134
# 3               at Richmond St       204
# 4                          NaN       120
# 5                Albert Street       204
# 6      in Toronto Eaton Centre       104
# 7                          NaN       209
# 8                 at Shuter St       150
# 9      in Toronto Eaton Centre       101
#
#                                     formattedAddress  \
# 0  [1 Richmond Street West (Yonge Street), Toront...
# 1  [189 Yonge St (btwn Queen St E & Shuter St), T...
# 2  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 3  [137 Yonge St (at Richmond St), Toronto ON M5C...
# 4         [220 Yonge St, Toronto ON M5B 2H1, Canada]
# 5  [483 Bay Street (Albert Street), Toronto ON M5...
# 6  [220 Yonge St, Unit B215-A (in Toronto Eaton C...
# 7  [60 Queen Street West, Toronto ON M5H 1A1, Can...
# 8  [178 Victoria St (at Shuter St), Toronto ON M5...
# 9  [220 Yonge Street, Space #3-131 (in Toronto Ea...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65156872562108...  43.651569 -79.379266
# 1  [{'label': 'display', 'lat': 43.65339379601958...  43.653394 -79.378507
# 2                                                NaN  43.653810 -79.380562
# 3  [{'label': 'display', 'lat': 43.65113563166627...  43.651136 -79.378797
# 4  [{'label': 'display', 'lat': 43.65351471121164...  43.653515 -79.380696
# 5  [{'label': 'display', 'lat': 43.65314383888587...  43.653144 -79.381980
# 6  [{'label': 'display', 'lat': 43.653557, 'lng':...  43.653557 -79.380400
# 7  [{'label': 'display', 'lat': 43.65200880087612...  43.652009 -79.381744
# 8  [{'label': 'display', 'lat': 43.65419470475393...  43.654195 -79.378891
# 9  [{'label': 'display', 'lat': 43.653688, 'lng':...  43.653688 -79.380120
#
#                     neighborhood postalCode state                        id
# 0                            NaN        NaN    ON  506db1a9e4b0a3f3b31412f0
# 1                            NaN    M5B 2H1    ON  4ad4c062f964a520b5f720e3
# 2  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3
# 3                            NaN    M5C 1W6    ON  4dc842f2e4cd5bc076711d90
# 4                 Downtown Yonge    M5B 2H1    ON  4b2a6eb8f964a52012a924e3
# 5                            NaN    M5G 2C9    ON  537773d1498e74a75bb75c1e
# 6                            NaN    M5B 2H1    ON  4bd0b30d41b9ef3b8fa0fae5
# 7                            NaN    M5H 1A1    ON  4ad4c05ef964a5208ef620e3
# 8                            NaN    M5B 1T7    ON  4ad4c061f964a520b3f720e3
# 9                            NaN    M5B 2H1    ON  4b749e98f964a5202ce82de3

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Coffee Shop', #Ecco
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup= label,  # label
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
